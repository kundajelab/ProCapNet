# %%
import os
import numpy as np
import pyBigWig
from collections import defaultdict
import matplotlib.pyplot as plt

# %%
proj_root = "/users/kcochran/projects/procapnet/"

which_genome = "hg38"

chroms_to_look_at = ["chr" + str(i+1) for i in range(22)] + ["chrX", "chrY"]

cell_types = ["K562", "A673", "CACO2", "CALU3", "HUVEC", "MCF10A"]

chrom_sizes_filepath = which_genome + "/" + which_genome + ".chrom.sizes"

# %%
def load_chrom_sizes(chrom_sizes_filepath):
    with open(chrom_sizes_filepath) as f:
        chrom_sizes_lines = [line.strip().split('\t') for line in f]
    chrom_sizes = {line[0] : int(line[1]) for line in chrom_sizes_lines}
    return chrom_sizes

chrom_sizes = load_chrom_sizes(chrom_sizes_filepath)

# %%
def get_bw_path(cell_type, pos_or_neg, which_genome = which_genome, proj_root=proj_root):
    assert pos_or_neg in ["pos", "neg"], pos_or_neg
    bws_dir = "bigwigs/" + which_genome + "/" + cell_type + "/genomewide/"
    bw_path = bws_dir + ".".join([cell_type, pos_or_neg, "bigWig"])
    assert os.path.exists(bw_path), bw_path
    return bw_path

# %%
# (this cell is old; the last cell in this notebook is the current version)
# (just keeping this so I remember what used to be broken)

for cell_type in cell_types:
    for strand in ["pos", "neg"]:
        print("\n")
        print(cell_type, strand)
        
        bw_path = get_bw_path(cell_type, strand)
        print("BigWig path:", bw_path)
        print("Exists?", os.path.exists(bw_path))
        
        # for hg38, this is about 24 GB
        print("File size:", "%0.1f" % (os.path.getsize(bw_path) / 1000000000) + "GB")
        
        try:
            bw = pyBigWig.open(bw_path, "r")
            
            a = bw.values("chr1", 103525338, 103525341, numpy=True)
            print("Some chr1 values:", a)
            
            bw.close()
        except:
            print("error")
            
        try:
            bw = pyBigWig.open(bw_path, "r")
            
            a = bw.values("chr17", 1000000, 1000003, numpy=True)
            print("Some chr17 values:", a)
            
            bw.close()
        except:
            print("error")
# Out:
# K562 pos
# BigWig path: bigwigs/hg38/K562/genomewide/K562.pos.bigWig
# Exists? True
# File size: 1.5GB
# error
# Some chr17 values: [nan nan nan]
#
#
# K562 neg
# BigWig path: bigwigs/hg38/K562/genomewide/K562.neg.bigWig
# Exists? True
# File size: 23.9GB
# Some chr1 values: [0.07293156 0.4248827  0.12350942]
# Some chr17 values: [0.00693997 0.01924002 0.00384026]
#
#
# A673 pos
# BigWig path: bigwigs/hg38/A673/genomewide/A673.pos.bigWig
# Exists? True
# File size: 24.0GB
# error
# error
#
#
# A673 neg
# BigWig path: bigwigs/hg38/A673/genomewide/A673.neg.bigWig
# Exists? True
# File size: 24.0GB
# Some chr1 values: [0.06382322 0.4426282  0.11472011]
# Some chr17 values: [0.0115502  0.04067886 0.00563827]
#
#
# CACO2 pos
# BigWig path: bigwigs/hg38/CACO2/genomewide/CACO2.pos.bigWig
# Exists? True
# File size: 24.1GB
# Some chr1 values: [3.4407833e-05 6.6062939e-06 1.9196763e-04]
# Some chr17 values: [0.00238057 0.00151144 0.02050897]
#
#
# CACO2 neg
# BigWig path: bigwigs/hg38/CACO2/genomewide/CACO2.neg.bigWig
# Exists? True
# File size: 24.1GB
# Some chr1 values: [0.04377054 0.31369984 0.03337388]
# Some chr17 values: [0.01436719 0.04488569 0.00419833]
#
#
# CALU3 pos
# BigWig path: bigwigs/hg38/CALU3/genomewide/CALU3.pos.bigWig
# Exists? True
# File size: 24.0GB
# Some chr1 values: [2.6182146e-05 7.4259533e-06 3.0680851e-04]
# Some chr17 values: [0.00617397 0.00262399 0.03995492]
#
#
# CALU3 neg
# BigWig path: bigwigs/hg38/CALU3/genomewide/CALU3.neg.bigWig
# Exists? True
# File size: 24.0GB
# Some chr1 values: [0.03741201 0.27823198 0.03268407]
# Some chr17 values: [0.01715214 0.08494413 0.00613924]
#
#
# HUVEC pos
# BigWig path: bigwigs/hg38/HUVEC/genomewide/HUVEC.pos.bigWig
# Exists? True
# File size: 24.1GB
# Some chr1 values: [2.4300121e-05 8.9212926e-06 2.1424635e-04]
# Some chr17 values: [0.00258208 0.00068838 0.01353408]
#
#
# HUVEC neg
# BigWig path: bigwigs/hg38/HUVEC/genomewide/HUVEC.neg.bigWig
# Exists? True
# File size: 24.1GB
# Some chr1 values: [0.01194454 0.09232388 0.01221823]
# Some chr17 values: [0.00819649 0.03561141 0.00256181]
#
#
# MCF10A pos
# BigWig path: bigwigs/hg38/MCF10A/genomewide/MCF10A.pos.bigWig
# Exists? True
# File size: 24.0GB
# Some chr1 values: [6.8754052e-05 5.4270447e-05 6.4689136e-04]
# Some chr17 values: [0.00931177 0.00501466 0.0429942 ]
#
#
# MCF10A neg
# BigWig path: bigwigs/hg38/MCF10A/genomewide/MCF10A.neg.bigWig
# Exists? True
# File size: 24.0GB
# Some chr1 values: [0.05781263 0.40969297 0.0905821 ]
# Some chr17 values: [0.01938896 0.12604833 0.00963228]
# [bwGetOverlappingIntervalsCore] Got an error
# [readRTreeIdx] Mismatch in the magic number!
# [bwOpen] bwg->idx is NULL bwg->hdr->dataOffset 0x2b4!
# [pyBwOpen] bw is NULL!
# [readRTreeIdx] Mismatch in the magic number!
# [bwOpen] bwg->idx is NULL bwg->hdr->dataOffset 0x2b4!
# [pyBwOpen] bw is NULL!

# %%
# broken: K562 pos, A673 pos

# %%
# were any of the individual chromosome bigwigs broken? (for hg38)

# %%
def get_chrom_bw_path(cell_type, pos_or_neg, chrom, which_genome = which_genome):
    assert pos_or_neg in ["pos", "neg"], pos_or_neg
    bws_dir = "/".join(["bigwigs", which_genome, cell_type, chrom]) + "/"
    bw_path = bws_dir + ".".join([chrom, cell_type, strand, "bigWig"])
    assert os.path.exists(bw_path), bw_path
    return bw_path

# %%
for cell_type in cell_types:
    for strand in ["pos", "neg"]:
        for chrom in chroms_to_look_at:
            print("\n")
            print(cell_type, strand, chrom)

            bw_path = get_chrom_bw_path(cell_type, strand, chrom)
            print("BigWig path:", bw_path)
            print("Exists?", os.path.exists(bw_path))

            # for hg38, this is about 24 GB
            print("File size:", "%0.1f" % (os.path.getsize(bw_path) / 1000000000) + "GB")

            try:
                bw = pyBigWig.open(bw_path, "r")

                a = bw.values(chrom, 0, chrom_sizes[chrom], numpy=True)
                    
                if np.mean(np.isnan(a)) > 0.25:
                    print("=================== NaNs!!!", np.mean(np.isnan(a)), chrom_sizes[chrom])

                if len(a) != chrom_sizes[chrom]:
                    print("=================== Wrong length????")
                    print(rand_start, len(a), chrom_sizes[chrom]) 

                bw.close()
            except:
                print("=================== error!!!")
# Out:
# K562 pos chr1
# BigWig path: bigwigs/hg38/K562/chr1/chr1.K562.pos.bigWig
# Exists? True
# File size: 1.8GB
#
#
# K562 pos chr2
# BigWig path: bigwigs/hg38/K562/chr2/chr2.K562.pos.bigWig
# Exists? True
# File size: 1.9GB
#
#
# K562 pos chr3
# BigWig path: bigwigs/hg38/K562/chr3/chr3.K562.pos.bigWig
# Exists? True
# File size: 1.6GB
#
#
# K562 pos chr4
# BigWig path: bigwigs/hg38/K562/chr4/chr4.K562.pos.bigWig
# Exists? True
# File size: 1.5GB
#
#
# K562 pos chr5
# BigWig path: bigwigs/hg38/K562/chr5/chr5.K562.pos.bigWig
# Exists? True
# File size: 1.4GB
#
#
# K562 pos chr6
# BigWig path: bigwigs/hg38/K562/chr6/chr6.K562.pos.bigWig
# Exists? True
# File size: 1.4GB
#
#
# K562 pos chr7
# BigWig path: bigwigs/hg38/K562/chr7/chr7.K562.pos.bigWig
# Exists? True
# File size: 1.3GB
#
#
# K562 pos chr8
# BigWig path: bigwigs/hg38/K562/chr8/chr8.K562.pos.bigWig
# Exists? True
# File size: 1.2GB
#
#
# K562 pos chr9
# BigWig path: bigwigs/hg38/K562/chr9/chr9.K562.pos.bigWig
# Exists? True
# File size: 1.0GB
#
#
# K562 pos chr10
# BigWig path: bigwigs/hg38/K562/chr10/chr10.K562.pos.bigWig
# Exists? True
# File size: 1.1GB
#
#
# K562 pos chr11
# BigWig path: bigwigs/hg38/K562/chr11/chr11.K562.pos.bigWig
# Exists? True
# File size: 1.1GB
#
#
# K562 pos chr12
# BigWig path: bigwigs/hg38/K562/chr12/chr12.K562.pos.bigWig
# Exists? True
# File size: 1.1GB
#
#
# K562 pos chr13
# BigWig path: bigwigs/hg38/K562/chr13/chr13.K562.pos.bigWig
# Exists? True
# File size: 0.8GB
#
#
# K562 pos chr14
# BigWig path: bigwigs/hg38/K562/chr14/chr14.K562.pos.bigWig
# Exists? True
# File size: 0.7GB
#
#
# K562 pos chr15
# BigWig path: bigwigs/hg38/K562/chr15/chr15.K562.pos.bigWig
# Exists? True
# File size: 0.7GB
#
#
# K562 pos chr16
# BigWig path: bigwigs/hg38/K562/chr16/chr16.K562.pos.bigWig
# Exists? True
# File size: 0.7GB
#
#
# K562 pos chr17
# BigWig path: bigwigs/hg38/K562/chr17/chr17.K562.pos.bigWig
# Exists? True
# File size: 0.7GB
#
#
# K562 pos chr18
# BigWig path: bigwigs/hg38/K562/chr18/chr18.K562.pos.bigWig
# Exists? True
# File size: 0.6GB
#
#
# K562 pos chr19
# BigWig path: bigwigs/hg38/K562/chr19/chr19.K562.pos.bigWig
# Exists? True
# File size: 0.4GB
#
#
# K562 pos chr20
# BigWig path: bigwigs/hg38/K562/chr20/chr20.K562.pos.bigWig
# Exists? True
# File size: 0.5GB
#
#
# K562 pos chr21
# BigWig path: bigwigs/hg38/K562/chr21/chr21.K562.pos.bigWig
# Exists? True
# File size: 0.3GB
#
#
# K562 pos chr22
# BigWig path: bigwigs/hg38/K562/chr22/chr22.K562.pos.bigWig
# Exists? True
# File size: 0.0GB
# =================== error!!!
#
#
# K562 pos chrX
# BigWig path: bigwigs/hg38/K562/chrX/chrX.K562.pos.bigWig
# Exists? True
# File size: 1.2GB
#
#
# K562 pos chrY
# BigWig path: bigwigs/hg38/K562/chrY/chrY.K562.pos.bigWig
# Exists? True
# File size: 0.2GB
# =================== NaNs!!! 0.5864351028261542 57227415
#
#
# K562 neg chr1
# BigWig path: bigwigs/hg38/K562/chr1/chr1.K562.neg.bigWig
# Exists? True
# File size: 1.8GB
#
#
# K562 neg chr2
# BigWig path: bigwigs/hg38/K562/chr2/chr2.K562.neg.bigWig
# Exists? True
# File size: 1.9GB
#
#
# K562 neg chr3
# BigWig path: bigwigs/hg38/K562/chr3/chr3.K562.neg.bigWig
# Exists? True
# File size: 1.6GB
#
#
# K562 neg chr4
# BigWig path: bigwigs/hg38/K562/chr4/chr4.K562.neg.bigWig
# Exists? True
# File size: 1.5GB
#
#
# K562 neg chr5
# BigWig path: bigwigs/hg38/K562/chr5/chr5.K562.neg.bigWig
# Exists? True
# File size: 1.4GB
#
#
# K562 neg chr6
# BigWig path: bigwigs/hg38/K562/chr6/chr6.K562.neg.bigWig
# Exists? True
# File size: 1.4GB
#
#
# K562 neg chr7
# BigWig path: bigwigs/hg38/K562/chr7/chr7.K562.neg.bigWig
# Exists? True
# File size: 1.3GB
#
#
# K562 neg chr8
# BigWig path: bigwigs/hg38/K562/chr8/chr8.K562.neg.bigWig
# Exists? True
# File size: 1.2GB
#
#
# K562 neg chr9
# BigWig path: bigwigs/hg38/K562/chr9/chr9.K562.neg.bigWig
# Exists? True
# File size: 1.0GB
#
#
# K562 neg chr10
# BigWig path: bigwigs/hg38/K562/chr10/chr10.K562.neg.bigWig
# Exists? True
# File size: 1.1GB
#
#
# K562 neg chr11
# BigWig path: bigwigs/hg38/K562/chr11/chr11.K562.neg.bigWig
# Exists? True
# File size: 1.1GB
#
#
# K562 neg chr12
# BigWig path: bigwigs/hg38/K562/chr12/chr12.K562.neg.bigWig
# Exists? True
# File size: 1.1GB
#
#
# K562 neg chr13
# BigWig path: bigwigs/hg38/K562/chr13/chr13.K562.neg.bigWig
# Exists? True
# File size: 0.8GB
#
#
# K562 neg chr14
# BigWig path: bigwigs/hg38/K562/chr14/chr14.K562.neg.bigWig
# Exists? True
# File size: 0.7GB
#
#
# K562 neg chr15
# BigWig path: bigwigs/hg38/K562/chr15/chr15.K562.neg.bigWig
# Exists? True
# File size: 0.7GB
#
#
# K562 neg chr16
# BigWig path: bigwigs/hg38/K562/chr16/chr16.K562.neg.bigWig
# Exists? True
# File size: 0.7GB
#
#
# K562 neg chr17
# BigWig path: bigwigs/hg38/K562/chr17/chr17.K562.neg.bigWig
# Exists? True
# File size: 0.7GB
#
#
# K562 neg chr18
# BigWig path: bigwigs/hg38/K562/chr18/chr18.K562.neg.bigWig
# Exists? True
# File size: 0.6GB
#
#
# K562 neg chr19
# BigWig path: bigwigs/hg38/K562/chr19/chr19.K562.neg.bigWig
# Exists? True
# File size: 0.4GB
#
#
# K562 neg chr20
# BigWig path: bigwigs/hg38/K562/chr20/chr20.K562.neg.bigWig
# Exists? True
# File size: 0.5GB
#
#
# K562 neg chr21
# BigWig path: bigwigs/hg38/K562/chr21/chr21.K562.neg.bigWig
# Exists? True
# File size: 0.3GB
#
#
# K562 neg chr22
# BigWig path: bigwigs/hg38/K562/chr22/chr22.K562.neg.bigWig
# Exists? True
# File size: 0.0GB
# =================== error!!!
#
#
# K562 neg chrX
# BigWig path: bigwigs/hg38/K562/chrX/chrX.K562.neg.bigWig
# Exists? True
# File size: 1.2GB
#
#
# K562 neg chrY
# BigWig path: bigwigs/hg38/K562/chrY/chrY.K562.neg.bigWig
# Exists? True
# File size: 0.2GB
# =================== NaNs!!! 0.5864351028261542 57227415
#
#
# A673 pos chr1
# BigWig path: bigwigs/hg38/A673/chr1/chr1.A673.pos.bigWig
# Exists? True
# File size: 1.9GB
#
#
# A673 pos chr2
# BigWig path: bigwigs/hg38/A673/chr2/chr2.A673.pos.bigWig
# Exists? True
# File size: 1.9GB
#
#
# A673 pos chr3
# BigWig path: bigwigs/hg38/A673/chr3/chr3.A673.pos.bigWig
# Exists? True
# File size: 1.6GB
#
#
# A673 pos chr4
# BigWig path: bigwigs/hg38/A673/chr4/chr4.A673.pos.bigWig
# Exists? True
# File size: 1.5GB
#
#
# A673 pos chr5
# BigWig path: bigwigs/hg38/A673/chr5/chr5.A673.pos.bigWig
# Exists? True
# File size: 1.4GB
#
#
# A673 pos chr6
# BigWig path: bigwigs/hg38/A673/chr6/chr6.A673.pos.bigWig
# Exists? True
# File size: 1.4GB
#
#
# A673 pos chr7
# BigWig path: bigwigs/hg38/A673/chr7/chr7.A673.pos.bigWig
# Exists? True
# File size: 1.3GB
#
#
# A673 pos chr9
# BigWig path: bigwigs/hg38/A673/chr9/chr9.A673.pos.bigWig
# Exists? True
# File size: 1.0GB
#
#
# A673 pos chr10
# BigWig path: bigwigs/hg38/A673/chr10/chr10.A673.pos.bigWig
# Exists? True
# File size: 1.1GB
#
#
# A673 pos chr11
# BigWig path: bigwigs/hg38/A673/chr11/chr11.A673.pos.bigWig
# Exists? True
# File size: 1.1GB
#
#
# A673 pos chr12
# BigWig path: bigwigs/hg38/A673/chr12/chr12.A673.pos.bigWig
# Exists? True
# File size: 1.1GB
#
#
# A673 pos chr13
# BigWig path: bigwigs/hg38/A673/chr13/chr13.A673.pos.bigWig
# Exists? True
# File size: 0.8GB
#
#
# A673 pos chr14
# BigWig path: bigwigs/hg38/A673/chr14/chr14.A673.pos.bigWig
# Exists? True
# File size: 0.7GB
#
#
# A673 pos chr15
# BigWig path: bigwigs/hg38/A673/chr15/chr15.A673.pos.bigWig
# Exists? True
# File size: 0.7GB
#
#
# A673 pos chr16
# BigWig path: bigwigs/hg38/A673/chr16/chr16.A673.pos.bigWig
# Exists? True
# File size: 0.7GB
#
#
# A673 pos chr17
# BigWig path: bigwigs/hg38/A673/chr17/chr17.A673.pos.bigWig
# Exists? True
# File size: 0.7GB
#
#
# A673 pos chr18
# BigWig path: bigwigs/hg38/A673/chr18/chr18.A673.pos.bigWig
# Exists? True
# File size: 0.6GB
#
#
# A673 pos chr19
# BigWig path: bigwigs/hg38/A673/chr19/chr19.A673.pos.bigWig
# Exists? True
# File size: 0.4GB
#
#
# A673 pos chr20
# BigWig path: bigwigs/hg38/A673/chr20/chr20.A673.pos.bigWig
# Exists? True
# File size: 0.5GB
#
#
# A673 pos chr21
# BigWig path: bigwigs/hg38/A673/chr21/chr21.A673.pos.bigWig
# Exists? True
# File size: 0.3GB
#
#
# A673 pos chr22
# BigWig path: bigwigs/hg38/A673/chr22/chr22.A673.pos.bigWig
# Exists? True
# File size: 0.3GB
# =================== NaNs!!! 0.2701472228560688 50818468
#
#
# A673 pos chrX
# BigWig path: bigwigs/hg38/A673/chrX/chrX.A673.pos.bigWig
# Exists? True
# File size: 1.2GB
#
#
# A673 pos chrY
# BigWig path: bigwigs/hg38/A673/chrY/chrY.A673.pos.bigWig
# Exists? True
# File size: 0.2GB
# =================== NaNs!!! 0.5864351028261542 57227415
#
#
# A673 neg chr1
# BigWig path: bigwigs/hg38/A673/chr1/chr1.A673.neg.bigWig
# Exists? True
# File size: 1.9GB
#
#
# A673 neg chr2
# BigWig path: bigwigs/hg38/A673/chr2/chr2.A673.neg.bigWig
# Exists? True
# File size: 1.9GB
#
#
# A673 neg chr3
# BigWig path: bigwigs/hg38/A673/chr3/chr3.A673.neg.bigWig
# Exists? True
# File size: 1.6GB
#
#
# A673 neg chr4
# BigWig path: bigwigs/hg38/A673/chr4/chr4.A673.neg.bigWig
# Exists? True
# File size: 1.5GB
#
#
# A673 neg chr5
# BigWig path: bigwigs/hg38/A673/chr5/chr5.A673.neg.bigWig
# Exists? True
# File size: 1.4GB
# A673 neg chr6
# BigWig path: bigwigs/hg38/A673/chr6/chr6.A673.neg.bigWig
# Exists? True
# File size: 1.4GB
#
#
# A673 neg chr7
# BigWig path: bigwigs/hg38/A673/chr7/chr7.A673.neg.bigWig
# Exists? True
# File size: 1.3GB
#
#
# A673 neg chr8
# BigWig path: bigwigs/hg38/A673/chr8/chr8.A673.neg.bigWig
# Exists? True
# File size: 1.2GB
#
#
# A673 neg chr9
# BigWig path: bigwigs/hg38/A673/chr9/chr9.A673.neg.bigWig
# Exists? True
# File size: 1.0GB
#
#
# A673 neg chr10
# BigWig path: bigwigs/hg38/A673/chr10/chr10.A673.neg.bigWig
# Exists? True
# File size: 1.1GB
#
#
# A673 neg chr11
# BigWig path: bigwigs/hg38/A673/chr11/chr11.A673.neg.bigWig
# Exists? True
# File size: 1.1GB
#
#
# A673 neg chr12
# BigWig path: bigwigs/hg38/A673/chr12/chr12.A673.neg.bigWig
# Exists? True
# File size: 1.1GB
#
#
# A673 neg chr13
# BigWig path: bigwigs/hg38/A673/chr13/chr13.A673.neg.bigWig
# Exists? True
# File size: 0.8GB
#
#
# A673 neg chr14
# BigWig path: bigwigs/hg38/A673/chr14/chr14.A673.neg.bigWig
# Exists? True
# File size: 0.7GB
#
#
# A673 neg chr15
# BigWig path: bigwigs/hg38/A673/chr15/chr15.A673.neg.bigWig
# Exists? True
# File size: 0.7GB
#
#
# A673 neg chr16
# BigWig path: bigwigs/hg38/A673/chr16/chr16.A673.neg.bigWig
# Exists? True
# File size: 0.7GB
#
#
# A673 neg chr17
# BigWig path: bigwigs/hg38/A673/chr17/chr17.A673.neg.bigWig
# Exists? True
# File size: 0.7GB
#
#
# A673 neg chr18
# BigWig path: bigwigs/hg38/A673/chr18/chr18.A673.neg.bigWig
# Exists? True
# File size: 0.6GB
#
#
# A673 neg chr19
# BigWig path: bigwigs/hg38/A673/chr19/chr19.A673.neg.bigWig
# Exists? True
# File size: 0.4GB
#
#
# A673 neg chr20
# BigWig path: bigwigs/hg38/A673/chr20/chr20.A673.neg.bigWig
# Exists? True
# File size: 0.5GB
#
#
# A673 neg chr21
# BigWig path: bigwigs/hg38/A673/chr21/chr21.A673.neg.bigWig
# Exists? True
# File size: 0.3GB
#
#
# A673 neg chr22
# BigWig path: bigwigs/hg38/A673/chr22/chr22.A673.neg.bigWig
# Exists? True
# File size: 0.3GB
# =================== NaNs!!! 0.2701472228560688 50818468
#
#
# A673 neg chrX
# BigWig path: bigwigs/hg38/A673/chrX/chrX.A673.neg.bigWig
# Exists? True
# File size: 1.2GB
#
#
# A673 neg chrY
# BigWig path: bigwigs/hg38/A673/chrY/chrY.A673.neg.bigWig
# Exists? True
# File size: 0.2GB
# =================== NaNs!!! 0.5864351028261542 57227415
#
#
# CACO2 pos chr1
# BigWig path: bigwigs/hg38/CACO2/chr1/chr1.CACO2.pos.bigWig
# Exists? True
# File size: 1.9GB
#
#
# CACO2 pos chr2
# BigWig path: bigwigs/hg38/CACO2/chr2/chr2.CACO2.pos.bigWig
# Exists? True
# File size: 1.9GB
#
#
# CACO2 pos chr3
# BigWig path: bigwigs/hg38/CACO2/chr3/chr3.CACO2.pos.bigWig
# Exists? True
# File size: 1.6GB
#
#
# CACO2 pos chr4
# BigWig path: bigwigs/hg38/CACO2/chr4/chr4.CACO2.pos.bigWig
# Exists? True
# File size: 1.5GB
#
#
# CACO2 pos chr5
# BigWig path: bigwigs/hg38/CACO2/chr5/chr5.CACO2.pos.bigWig
# Exists? True
# File size: 1.4GB
#
#
# CACO2 pos chr6
# BigWig path: bigwigs/hg38/CACO2/chr6/chr6.CACO2.pos.bigWig
# Exists? True
# File size: 1.4GB
#
#
# CACO2 pos chr7
# BigWig path: bigwigs/hg38/CACO2/chr7/chr7.CACO2.pos.bigWig
# Exists? True
# File size: 1.3GB
#
#
# CACO2 pos chr8
# BigWig path: bigwigs/hg38/CACO2/chr8/chr8.CACO2.pos.bigWig
# Exists? True
# File size: 1.2GB
#
#
# CACO2 pos chr9
# BigWig path: bigwigs/hg38/CACO2/chr9/chr9.CACO2.pos.bigWig
# Exists? True
# File size: 1.0GB
#
#
# CACO2 pos chr10
# BigWig path: bigwigs/hg38/CACO2/chr10/chr10.CACO2.pos.bigWig
# Exists? True
# File size: 1.1GB
#
#
# CACO2 pos chr11
# BigWig path: bigwigs/hg38/CACO2/chr11/chr11.CACO2.pos.bigWig
# Exists? True
# File size: 1.1GB
#
#
# CACO2 pos chr12
# BigWig path: bigwigs/hg38/CACO2/chr12/chr12.CACO2.pos.bigWig
# Exists? True
# File size: 1.1GB
#
#
# CACO2 pos chr13
# BigWig path: bigwigs/hg38/CACO2/chr13/chr13.CACO2.pos.bigWig
# Exists? True
# File size: 0.8GB
#
#
# CACO2 pos chr14
# BigWig path: bigwigs/hg38/CACO2/chr14/chr14.CACO2.pos.bigWig
# Exists? True
# File size: 0.7GB
#
#
# CACO2 pos chr15
# BigWig path: bigwigs/hg38/CACO2/chr15/chr15.CACO2.pos.bigWig
# Exists? True
# File size: 0.7GB
#
#
# CACO2 pos chr16
# BigWig path: bigwigs/hg38/CACO2/chr16/chr16.CACO2.pos.bigWig
# Exists? True
# File size: 0.7GB
#
#
# CACO2 pos chr17
# BigWig path: bigwigs/hg38/CACO2/chr17/chr17.CACO2.pos.bigWig
# Exists? True
# File size: 0.7GB
#
#
# CACO2 pos chr18
# BigWig path: bigwigs/hg38/CACO2/chr18/chr18.CACO2.pos.bigWig
# Exists? True
# File size: 0.6GB
#
#
# CACO2 pos chr19
# BigWig path: bigwigs/hg38/CACO2/chr19/chr19.CACO2.pos.bigWig
# Exists? True
# File size: 0.5GB
#
#
# CACO2 pos chr20
# BigWig path: bigwigs/hg38/CACO2/chr20/chr20.CACO2.pos.bigWig
# Exists? True
# File size: 0.5GB
#
#
# CACO2 pos chr21
# BigWig path: bigwigs/hg38/CACO2/chr21/chr21.CACO2.pos.bigWig
# Exists? True
# File size: 0.3GB
#
#
# CACO2 pos chr22
# BigWig path: bigwigs/hg38/CACO2/chr22/chr22.CACO2.pos.bigWig
# Exists? True
# File size: 0.3GB
# =================== NaNs!!! 0.2701472228560688 50818468
#
#
# CACO2 pos chrX
# BigWig path: bigwigs/hg38/CACO2/chrX/chrX.CACO2.pos.bigWig
# Exists? True
# File size: 1.3GB
#
#
# CACO2 pos chrY
# BigWig path: bigwigs/hg38/CACO2/chrY/chrY.CACO2.pos.bigWig
# Exists? True
# File size: 0.2GB
# =================== NaNs!!! 0.5864351028261542 57227415
#
#
# CACO2 neg chr1
# BigWig path: bigwigs/hg38/CACO2/chr1/chr1.CACO2.neg.bigWig
# Exists? True
# File size: 1.9GB
#
#
# CACO2 neg chr2
# BigWig path: bigwigs/hg38/CACO2/chr2/chr2.CACO2.neg.bigWig
# Exists? True
# File size: 1.9GB
#
#
# CACO2 neg chr3
# BigWig path: bigwigs/hg38/CACO2/chr3/chr3.CACO2.neg.bigWig
# Exists? True
# File size: 1.6GB
#
#
# CACO2 neg chr4
# BigWig path: bigwigs/hg38/CACO2/chr4/chr4.CACO2.neg.bigWig
# Exists? True
# File size: 1.5GB
#
#
# CACO2 neg chr5
# BigWig path: bigwigs/hg38/CACO2/chr5/chr5.CACO2.neg.bigWig
# Exists? True
# File size: 1.4GB
#
#
# CACO2 neg chr6
# BigWig path: bigwigs/hg38/CACO2/chr6/chr6.CACO2.neg.bigWig
# Exists? True
# File size: 1.4GB
#
#
# CACO2 neg chr7
# BigWig path: bigwigs/hg38/CACO2/chr7/chr7.CACO2.neg.bigWig
# Exists? True
# File size: 1.3GB
#
#
# CACO2 neg chr8
# BigWig path: bigwigs/hg38/CACO2/chr8/chr8.CACO2.neg.bigWig
# Exists? True
# File size: 1.2GB
#
#
# CACO2 neg chr9
# BigWig path: bigwigs/hg38/CACO2/chr9/chr9.CACO2.neg.bigWig
# Exists? True
# File size: 1.0GB
#
#
# CACO2 neg chr10
# BigWig path: bigwigs/hg38/CACO2/chr10/chr10.CACO2.neg.bigWig
# Exists? True
# File size: 1.1GB
#
#
# CACO2 neg chr11
# BigWig path: bigwigs/hg38/CACO2/chr11/chr11.CACO2.neg.bigWig
# Exists? True
# File size: 1.1GB
#
#
# CACO2 neg chr12
# BigWig path: bigwigs/hg38/CACO2/chr12/chr12.CACO2.neg.bigWig
# Exists? True
# File size: 1.1GB
#
#
# CACO2 neg chr13
# BigWig path: bigwigs/hg38/CACO2/chr13/chr13.CACO2.neg.bigWig
# Exists? True
# File size: 0.8GB
#
#
# CACO2 neg chr14
# BigWig path: bigwigs/hg38/CACO2/chr14/chr14.CACO2.neg.bigWig
# Exists? True
# File size: 0.7GB
#
#
# CACO2 neg chr15
# BigWig path: bigwigs/hg38/CACO2/chr15/chr15.CACO2.neg.bigWig
# Exists? True
# File size: 0.7GB
#
#
# CACO2 neg chr16
# BigWig path: bigwigs/hg38/CACO2/chr16/chr16.CACO2.neg.bigWig
# Exists? True
# File size: 0.7GB
#
#
# CACO2 neg chr17
# BigWig path: bigwigs/hg38/CACO2/chr17/chr17.CACO2.neg.bigWig
# Exists? True
# File size: 0.7GB
#
#
# CACO2 neg chr18
# BigWig path: bigwigs/hg38/CACO2/chr18/chr18.CACO2.neg.bigWig
# Exists? True
# File size: 0.6GB
#
#
# CACO2 neg chr19
# BigWig path: bigwigs/hg38/CACO2/chr19/chr19.CACO2.neg.bigWig
# Exists? True
# File size: 0.5GB
#
#
# CACO2 neg chr20
# BigWig path: bigwigs/hg38/CACO2/chr20/chr20.CACO2.neg.bigWig
# Exists? True
# File size: 0.5GB
#
#
# CACO2 neg chr21
# BigWig path: bigwigs/hg38/CACO2/chr21/chr21.CACO2.neg.bigWig
# Exists? True
# File size: 0.3GB
#
#
# CACO2 neg chr22
# BigWig path: bigwigs/hg38/CACO2/chr22/chr22.CACO2.neg.bigWig
# Exists? True
# File size: 0.3GB
# =================== NaNs!!! 0.2701472228560688 50818468
#
#
# CACO2 neg chrX
# BigWig path: bigwigs/hg38/CACO2/chrX/chrX.CACO2.neg.bigWig
# Exists? True
# File size: 1.3GB
#
#
# CACO2 neg chrY
# BigWig path: bigwigs/hg38/CACO2/chrY/chrY.CACO2.neg.bigWig
# Exists? True
# File size: 0.2GB
# =================== NaNs!!! 0.5864351028261542 57227415
#
#
# CALU3 pos chr1
# BigWig path: bigwigs/hg38/CALU3/chr1/chr1.CALU3.pos.bigWig
# Exists? True
# File size: 1.9GB
#
#
# CALU3 pos chr2
# BigWig path: bigwigs/hg38/CALU3/chr2/chr2.CALU3.pos.bigWig
# Exists? True
# File size: 1.9GB
#
#
# CALU3 pos chr3
# BigWig path: bigwigs/hg38/CALU3/chr3/chr3.CALU3.pos.bigWig
# Exists? True
# File size: 1.6GB
#
#
# CALU3 pos chr4
# BigWig path: bigwigs/hg38/CALU3/chr4/chr4.CALU3.pos.bigWig
# Exists? True
# File size: 1.5GB
#
#
# CALU3 pos chr5
# BigWig path: bigwigs/hg38/CALU3/chr5/chr5.CALU3.pos.bigWig
# Exists? True
# File size: 1.4GB
#
#
# CALU3 pos chr6
# BigWig path: bigwigs/hg38/CALU3/chr6/chr6.CALU3.pos.bigWig
# Exists? True
# File size: 1.4GB
#
#
# CALU3 pos chr7
# BigWig path: bigwigs/hg38/CALU3/chr7/chr7.CALU3.pos.bigWig
# Exists? True
# File size: 1.3GB
# CALU3 pos chr8
# BigWig path: bigwigs/hg38/CALU3/chr8/chr8.CALU3.pos.bigWig
# Exists? True
# File size: 1.2GB
#
#
# CALU3 pos chr9
# BigWig path: bigwigs/hg38/CALU3/chr9/chr9.CALU3.pos.bigWig
# Exists? True
# File size: 1.0GB
#
#
# CALU3 pos chr10
# BigWig path: bigwigs/hg38/CALU3/chr10/chr10.CALU3.pos.bigWig
# Exists? True
# File size: 1.1GB
#
#
# CALU3 pos chr11
# BigWig path: bigwigs/hg38/CALU3/chr11/chr11.CALU3.pos.bigWig
# Exists? True
# File size: 1.1GB
#
#
# CALU3 pos chr12
# BigWig path: bigwigs/hg38/CALU3/chr12/chr12.CALU3.pos.bigWig
# Exists? True
# File size: 1.1GB
#
#
# CALU3 pos chr13
# BigWig path: bigwigs/hg38/CALU3/chr13/chr13.CALU3.pos.bigWig
# Exists? True
# File size: 0.8GB
#
#
# CALU3 pos chr14
# BigWig path: bigwigs/hg38/CALU3/chr14/chr14.CALU3.pos.bigWig
# Exists? True
# File size: 0.7GB
#
#
# CALU3 pos chr15
# BigWig path: bigwigs/hg38/CALU3/chr15/chr15.CALU3.pos.bigWig
# Exists? True
# File size: 0.7GB
#
#
# CALU3 pos chr16
# BigWig path: bigwigs/hg38/CALU3/chr16/chr16.CALU3.pos.bigWig
# Exists? True
# File size: 0.7GB
#
#
# CALU3 pos chr17
# BigWig path: bigwigs/hg38/CALU3/chr17/chr17.CALU3.pos.bigWig
# Exists? True
# File size: 0.7GB
#
#
# CALU3 pos chr18
# BigWig path: bigwigs/hg38/CALU3/chr18/chr18.CALU3.pos.bigWig
# Exists? True
# File size: 0.6GB
#
#
# CALU3 pos chr19
# BigWig path: bigwigs/hg38/CALU3/chr19/chr19.CALU3.pos.bigWig
# Exists? True
# File size: 0.5GB
#
#
# CALU3 pos chr20
# BigWig path: bigwigs/hg38/CALU3/chr20/chr20.CALU3.pos.bigWig
# Exists? True
# File size: 0.5GB
#
#
# CALU3 pos chr21
# BigWig path: bigwigs/hg38/CALU3/chr21/chr21.CALU3.pos.bigWig
# Exists? True
# File size: 0.3GB
#
#
# CALU3 pos chr22
# BigWig path: bigwigs/hg38/CALU3/chr22/chr22.CALU3.pos.bigWig
# Exists? True
# File size: 0.3GB
# =================== NaNs!!! 0.2701472228560688 50818468
#
#
# CALU3 pos chrX
# BigWig path: bigwigs/hg38/CALU3/chrX/chrX.CALU3.pos.bigWig
# Exists? True
# File size: 1.3GB
#
#
# CALU3 pos chrY
# BigWig path: bigwigs/hg38/CALU3/chrY/chrY.CALU3.pos.bigWig
# Exists? True
# File size: 0.2GB
# =================== NaNs!!! 0.5864351028261542 57227415
#
#
# CALU3 neg chr1
# BigWig path: bigwigs/hg38/CALU3/chr1/chr1.CALU3.neg.bigWig
# Exists? True
# File size: 1.9GB
#
#
# CALU3 neg chr2
# BigWig path: bigwigs/hg38/CALU3/chr2/chr2.CALU3.neg.bigWig
# Exists? True
# File size: 1.9GB
#
#
# CALU3 neg chr3
# BigWig path: bigwigs/hg38/CALU3/chr3/chr3.CALU3.neg.bigWig
# Exists? True
# File size: 1.6GB
#
#
# CALU3 neg chr4
# BigWig path: bigwigs/hg38/CALU3/chr4/chr4.CALU3.neg.bigWig
# Exists? True
# File size: 1.5GB
#
#
# CALU3 neg chr5
# BigWig path: bigwigs/hg38/CALU3/chr5/chr5.CALU3.neg.bigWig
# Exists? True
# File size: 1.4GB
#
#
# CALU3 neg chr6
# BigWig path: bigwigs/hg38/CALU3/chr6/chr6.CALU3.neg.bigWig
# Exists? True
# File size: 1.4GB
#
#
# CALU3 neg chr7
# BigWig path: bigwigs/hg38/CALU3/chr7/chr7.CALU3.neg.bigWig
# Exists? True
# File size: 1.3GB
#
#
# CALU3 neg chr8
# BigWig path: bigwigs/hg38/CALU3/chr8/chr8.CALU3.neg.bigWig
# Exists? True
# File size: 1.2GB
#
#
# CALU3 neg chr9
# BigWig path: bigwigs/hg38/CALU3/chr9/chr9.CALU3.neg.bigWig
# Exists? True
# File size: 1.0GB
#
#
# CALU3 neg chr10
# BigWig path: bigwigs/hg38/CALU3/chr10/chr10.CALU3.neg.bigWig
# Exists? True
# File size: 1.1GB
#
#
# CALU3 neg chr11
# BigWig path: bigwigs/hg38/CALU3/chr11/chr11.CALU3.neg.bigWig
# Exists? True
# File size: 1.1GB
#
#
# CALU3 neg chr12
# BigWig path: bigwigs/hg38/CALU3/chr12/chr12.CALU3.neg.bigWig
# Exists? True
# File size: 1.1GB
#
#
# CALU3 neg chr13
# BigWig path: bigwigs/hg38/CALU3/chr13/chr13.CALU3.neg.bigWig
# Exists? True
# File size: 0.8GB
#
#
# CALU3 neg chr14
# BigWig path: bigwigs/hg38/CALU3/chr14/chr14.CALU3.neg.bigWig
# Exists? True
# File size: 0.7GB
#
#
# CALU3 neg chr15
# BigWig path: bigwigs/hg38/CALU3/chr15/chr15.CALU3.neg.bigWig
# Exists? True
# File size: 0.7GB
#
#
# CALU3 neg chr16
# BigWig path: bigwigs/hg38/CALU3/chr16/chr16.CALU3.neg.bigWig
# Exists? True
# File size: 0.7GB
#
#
# CALU3 neg chr17
# BigWig path: bigwigs/hg38/CALU3/chr17/chr17.CALU3.neg.bigWig
# Exists? True
# File size: 0.7GB
#
#
# CALU3 neg chr18
# BigWig path: bigwigs/hg38/CALU3/chr18/chr18.CALU3.neg.bigWig
# Exists? True
# File size: 0.6GB
#
#
# CALU3 neg chr19
# BigWig path: bigwigs/hg38/CALU3/chr19/chr19.CALU3.neg.bigWig
# Exists? True
# File size: 0.5GB
#
#
# CALU3 neg chr20
# BigWig path: bigwigs/hg38/CALU3/chr20/chr20.CALU3.neg.bigWig
# Exists? True
# File size: 0.5GB
#
#
# CALU3 neg chr21
# BigWig path: bigwigs/hg38/CALU3/chr21/chr21.CALU3.neg.bigWig
# Exists? True
# File size: 0.3GB
#
#
# CALU3 neg chr22
# BigWig path: bigwigs/hg38/CALU3/chr22/chr22.CALU3.neg.bigWig
# Exists? True
# File size: 0.3GB
# =================== NaNs!!! 0.2701472228560688 50818468
#
#
# CALU3 neg chrX
# BigWig path: bigwigs/hg38/CALU3/chrX/chrX.CALU3.neg.bigWig
# Exists? True
# File size: 1.3GB
#
#
# CALU3 neg chrY
# BigWig path: bigwigs/hg38/CALU3/chrY/chrY.CALU3.neg.bigWig
# Exists? True
# File size: 0.2GB
# =================== NaNs!!! 0.5864351028261542 57227415
#
#
# HUVEC pos chr1
# BigWig path: bigwigs/hg38/HUVEC/chr1/chr1.HUVEC.pos.bigWig
# Exists? True
# File size: 1.9GB
#
#
# HUVEC pos chr2
# BigWig path: bigwigs/hg38/HUVEC/chr2/chr2.HUVEC.pos.bigWig
# Exists? True
# File size: 1.9GB
#
#
# HUVEC pos chr3
# BigWig path: bigwigs/hg38/HUVEC/chr3/chr3.HUVEC.pos.bigWig
# Exists? True
# File size: 1.6GB
#
#
# HUVEC pos chr4
# BigWig path: bigwigs/hg38/HUVEC/chr4/chr4.HUVEC.pos.bigWig
# Exists? True
# File size: 1.5GB
#
#
# HUVEC pos chr5
# BigWig path: bigwigs/hg38/HUVEC/chr5/chr5.HUVEC.pos.bigWig
# Exists? True
# File size: 1.4GB
#
#
# HUVEC pos chr6
# BigWig path: bigwigs/hg38/HUVEC/chr6/chr6.HUVEC.pos.bigWig
# Exists? True
# File size: 1.4GB
#
#
# HUVEC pos chr7
# BigWig path: bigwigs/hg38/HUVEC/chr7/chr7.HUVEC.pos.bigWig
# Exists? True
# File size: 1.3GB
#
#
# HUVEC pos chr8
# BigWig path: bigwigs/hg38/HUVEC/chr8/chr8.HUVEC.pos.bigWig
# Exists? True
# File size: 1.2GB
#
#
# HUVEC pos chr9
# BigWig path: bigwigs/hg38/HUVEC/chr9/chr9.HUVEC.pos.bigWig
# Exists? True
# File size: 1.0GB
#
#
# HUVEC pos chr10
# BigWig path: bigwigs/hg38/HUVEC/chr10/chr10.HUVEC.pos.bigWig
# Exists? True
# File size: 1.1GB
#
#
# HUVEC pos chr11
# BigWig path: bigwigs/hg38/HUVEC/chr11/chr11.HUVEC.pos.bigWig
# Exists? True
# File size: 1.1GB
#
#
# HUVEC pos chr12
# BigWig path: bigwigs/hg38/HUVEC/chr12/chr12.HUVEC.pos.bigWig
# Exists? True
# File size: 1.1GB
#
#
# HUVEC pos chr13
# BigWig path: bigwigs/hg38/HUVEC/chr13/chr13.HUVEC.pos.bigWig
# Exists? True
# File size: 0.8GB
#
#
# HUVEC pos chr14
# BigWig path: bigwigs/hg38/HUVEC/chr14/chr14.HUVEC.pos.bigWig
# Exists? True
# File size: 0.7GB
#
#
# HUVEC pos chr15
# BigWig path: bigwigs/hg38/HUVEC/chr15/chr15.HUVEC.pos.bigWig
# Exists? True
# File size: 0.7GB
#
#
# HUVEC pos chr16
# BigWig path: bigwigs/hg38/HUVEC/chr16/chr16.HUVEC.pos.bigWig
# Exists? True
# File size: 0.7GB
#
#
# HUVEC pos chr17
# BigWig path: bigwigs/hg38/HUVEC/chr17/chr17.HUVEC.pos.bigWig
# Exists? True
# File size: 0.7GB
#
#
# HUVEC pos chr18
# BigWig path: bigwigs/hg38/HUVEC/chr18/chr18.HUVEC.pos.bigWig
# Exists? True
# File size: 0.6GB
#
#
# HUVEC pos chr19
# BigWig path: bigwigs/hg38/HUVEC/chr19/chr19.HUVEC.pos.bigWig
# Exists? True
# File size: 0.5GB
#
#
# HUVEC pos chr20
# BigWig path: bigwigs/hg38/HUVEC/chr20/chr20.HUVEC.pos.bigWig
# Exists? True
# File size: 0.5GB
#
#
# HUVEC pos chr21
# BigWig path: bigwigs/hg38/HUVEC/chr21/chr21.HUVEC.pos.bigWig
# Exists? True
# File size: 0.3GB
#
#
# HUVEC pos chr22
# BigWig path: bigwigs/hg38/HUVEC/chr22/chr22.HUVEC.pos.bigWig
# Exists? True
# File size: 0.3GB
# =================== NaNs!!! 0.2701472228560688 50818468
#
#
# HUVEC pos chrX
# BigWig path: bigwigs/hg38/HUVEC/chrX/chrX.HUVEC.pos.bigWig
# Exists? True
# File size: 1.3GB
#
#
# HUVEC pos chrY
# BigWig path: bigwigs/hg38/HUVEC/chrY/chrY.HUVEC.pos.bigWig
# Exists? True
# File size: 0.2GB
# =================== NaNs!!! 0.5864351028261542 57227415
#
#
# HUVEC neg chr1
# BigWig path: bigwigs/hg38/HUVEC/chr1/chr1.HUVEC.neg.bigWig
# Exists? True
# File size: 1.9GB
#
#
# HUVEC neg chr2
# BigWig path: bigwigs/hg38/HUVEC/chr2/chr2.HUVEC.neg.bigWig
# Exists? True
# File size: 1.9GB
#
#
# HUVEC neg chr3
# BigWig path: bigwigs/hg38/HUVEC/chr3/chr3.HUVEC.neg.bigWig
# Exists? True
# File size: 1.6GB
#
#
# HUVEC neg chr4
# BigWig path: bigwigs/hg38/HUVEC/chr4/chr4.HUVEC.neg.bigWig
# Exists? True
# File size: 1.5GB
#
#
# HUVEC neg chr5
# BigWig path: bigwigs/hg38/HUVEC/chr5/chr5.HUVEC.neg.bigWig
# Exists? True
# File size: 1.4GB
#
#
# HUVEC neg chr6
# BigWig path: bigwigs/hg38/HUVEC/chr6/chr6.HUVEC.neg.bigWig
# Exists? True
# File size: 1.4GB
#
#
# HUVEC neg chr7
# BigWig path: bigwigs/hg38/HUVEC/chr7/chr7.HUVEC.neg.bigWig
# Exists? True
# File size: 1.3GB
#
#
# HUVEC neg chr8
# BigWig path: bigwigs/hg38/HUVEC/chr8/chr8.HUVEC.neg.bigWig
# Exists? True
# File size: 1.2GB
#
#
# HUVEC neg chr9
# BigWig path: bigwigs/hg38/HUVEC/chr9/chr9.HUVEC.neg.bigWig
# Exists? True
# File size: 1.0GB
# HUVEC neg chr10
# BigWig path: bigwigs/hg38/HUVEC/chr10/chr10.HUVEC.neg.bigWig
# Exists? True
# File size: 1.1GB
#
#
# HUVEC neg chr11
# BigWig path: bigwigs/hg38/HUVEC/chr11/chr11.HUVEC.neg.bigWig
# Exists? True
# File size: 1.1GB
#
#
# HUVEC neg chr12
# BigWig path: bigwigs/hg38/HUVEC/chr12/chr12.HUVEC.neg.bigWig
# Exists? True
# File size: 1.1GB
#
#
# HUVEC neg chr13
# BigWig path: bigwigs/hg38/HUVEC/chr13/chr13.HUVEC.neg.bigWig
# Exists? True
# File size: 0.8GB
#
#
# HUVEC neg chr14
# BigWig path: bigwigs/hg38/HUVEC/chr14/chr14.HUVEC.neg.bigWig
# Exists? True
# File size: 0.7GB
#
#
# HUVEC neg chr15
# BigWig path: bigwigs/hg38/HUVEC/chr15/chr15.HUVEC.neg.bigWig
# Exists? True
# File size: 0.7GB
#
#
# HUVEC neg chr16
# BigWig path: bigwigs/hg38/HUVEC/chr16/chr16.HUVEC.neg.bigWig
# Exists? True
# File size: 0.7GB
#
#
# HUVEC neg chr17
# BigWig path: bigwigs/hg38/HUVEC/chr17/chr17.HUVEC.neg.bigWig
# Exists? True
# File size: 0.7GB
#
#
# HUVEC neg chr18
# BigWig path: bigwigs/hg38/HUVEC/chr18/chr18.HUVEC.neg.bigWig
# Exists? True
# File size: 0.6GB
#
#
# HUVEC neg chr19
# BigWig path: bigwigs/hg38/HUVEC/chr19/chr19.HUVEC.neg.bigWig
# Exists? True
# File size: 0.5GB
#
#
# HUVEC neg chr20
# BigWig path: bigwigs/hg38/HUVEC/chr20/chr20.HUVEC.neg.bigWig
# Exists? True
# File size: 0.5GB
#
#
# HUVEC neg chr21
# BigWig path: bigwigs/hg38/HUVEC/chr21/chr21.HUVEC.neg.bigWig
# Exists? True
# File size: 0.3GB
#
#
# HUVEC neg chr22
# BigWig path: bigwigs/hg38/HUVEC/chr22/chr22.HUVEC.neg.bigWig
# Exists? True
# File size: 0.3GB
# =================== NaNs!!! 0.2701472228560688 50818468
#
#
# HUVEC neg chrX
# BigWig path: bigwigs/hg38/HUVEC/chrX/chrX.HUVEC.neg.bigWig
# Exists? True
# File size: 1.3GB
#
#
# HUVEC neg chrY
# BigWig path: bigwigs/hg38/HUVEC/chrY/chrY.HUVEC.neg.bigWig
# Exists? True
# File size: 0.2GB
# =================== NaNs!!! 0.5864351028261542 57227415
#
#
# MCF10A pos chr1
# BigWig path: bigwigs/hg38/MCF10A/chr1/chr1.MCF10A.pos.bigWig
# Exists? True
# File size: 1.9GB
#
#
# MCF10A pos chr2
# BigWig path: bigwigs/hg38/MCF10A/chr2/chr2.MCF10A.pos.bigWig
# Exists? True
# File size: 1.9GB
#
#
# MCF10A pos chr3
# BigWig path: bigwigs/hg38/MCF10A/chr3/chr3.MCF10A.pos.bigWig
# Exists? True
# File size: 1.6GB
#
#
# MCF10A pos chr4
# BigWig path: bigwigs/hg38/MCF10A/chr4/chr4.MCF10A.pos.bigWig
# Exists? True
# File size: 1.5GB
#
#
# MCF10A pos chr5
# BigWig path: bigwigs/hg38/MCF10A/chr5/chr5.MCF10A.pos.bigWig
# Exists? True
# File size: 1.4GB
#
#
# MCF10A pos chr6
# BigWig path: bigwigs/hg38/MCF10A/chr6/chr6.MCF10A.pos.bigWig
# Exists? True
# File size: 1.4GB
#
#
# MCF10A pos chr7
# BigWig path: bigwigs/hg38/MCF10A/chr7/chr7.MCF10A.pos.bigWig
# Exists? True
# File size: 1.3GB
#
#
# MCF10A pos chr8
# BigWig path: bigwigs/hg38/MCF10A/chr8/chr8.MCF10A.pos.bigWig
# Exists? True
# File size: 1.2GB
#
#
# MCF10A pos chr9
# BigWig path: bigwigs/hg38/MCF10A/chr9/chr9.MCF10A.pos.bigWig
# Exists? True
# File size: 1.0GB
#
#
# MCF10A pos chr10
# BigWig path: bigwigs/hg38/MCF10A/chr10/chr10.MCF10A.pos.bigWig
# Exists? True
# File size: 1.1GB
#
#
# MCF10A pos chr11
# BigWig path: bigwigs/hg38/MCF10A/chr11/chr11.MCF10A.pos.bigWig
# Exists? True
# File size: 1.1GB
#
#
# MCF10A pos chr12
# BigWig path: bigwigs/hg38/MCF10A/chr12/chr12.MCF10A.pos.bigWig
# Exists? True
# File size: 1.1GB
#
#
# MCF10A pos chr13
# BigWig path: bigwigs/hg38/MCF10A/chr13/chr13.MCF10A.pos.bigWig
# Exists? True
# File size: 0.8GB
#
#
# MCF10A pos chr14
# BigWig path: bigwigs/hg38/MCF10A/chr14/chr14.MCF10A.pos.bigWig
# Exists? True
# File size: 0.7GB
#
#
# MCF10A pos chr15
# BigWig path: bigwigs/hg38/MCF10A/chr15/chr15.MCF10A.pos.bigWig
# Exists? True
# File size: 0.7GB
#
#
# MCF10A pos chr16
# BigWig path: bigwigs/hg38/MCF10A/chr16/chr16.MCF10A.pos.bigWig
# Exists? True
# File size: 0.7GB
#
#
# MCF10A pos chr17
# BigWig path: bigwigs/hg38/MCF10A/chr17/chr17.MCF10A.pos.bigWig
# Exists? True
# File size: 0.7GB
#
#
# MCF10A pos chr18
# BigWig path: bigwigs/hg38/MCF10A/chr18/chr18.MCF10A.pos.bigWig
# Exists? True
# File size: 0.6GB
#
#
# MCF10A pos chr19
# BigWig path: bigwigs/hg38/MCF10A/chr19/chr19.MCF10A.pos.bigWig
# Exists? True
# File size: 0.4GB
#
#
# MCF10A pos chr20
# BigWig path: bigwigs/hg38/MCF10A/chr20/chr20.MCF10A.pos.bigWig
# Exists? True
# File size: 0.5GB
#
#
# MCF10A pos chr21
# BigWig path: bigwigs/hg38/MCF10A/chr21/chr21.MCF10A.pos.bigWig
# Exists? True
# File size: 0.3GB
#
#
# MCF10A pos chr22
# BigWig path: bigwigs/hg38/MCF10A/chr22/chr22.MCF10A.pos.bigWig
# Exists? True
# File size: 0.3GB
# =================== NaNs!!! 0.2701472228560688 50818468
#
#
# MCF10A pos chrX
# BigWig path: bigwigs/hg38/MCF10A/chrX/chrX.MCF10A.pos.bigWig
# Exists? True
# File size: 1.2GB
#
#
# MCF10A pos chrY
# BigWig path: bigwigs/hg38/MCF10A/chrY/chrY.MCF10A.pos.bigWig
# Exists? True
# File size: 0.2GB
# =================== NaNs!!! 0.5864351028261542 57227415
#
#
# MCF10A neg chr1
# BigWig path: bigwigs/hg38/MCF10A/chr1/chr1.MCF10A.neg.bigWig
# Exists? True
# File size: 1.9GB
#
#
# MCF10A neg chr2
# BigWig path: bigwigs/hg38/MCF10A/chr2/chr2.MCF10A.neg.bigWig
# Exists? True
# File size: 1.9GB
#
#
# MCF10A neg chr3
# BigWig path: bigwigs/hg38/MCF10A/chr3/chr3.MCF10A.neg.bigWig
# Exists? True
# File size: 1.6GB
#
#
# MCF10A neg chr4
# BigWig path: bigwigs/hg38/MCF10A/chr4/chr4.MCF10A.neg.bigWig
# Exists? True
# File size: 1.5GB
#
#
# MCF10A neg chr5
# BigWig path: bigwigs/hg38/MCF10A/chr5/chr5.MCF10A.neg.bigWig
# Exists? True
# File size: 1.4GB
#
#
# MCF10A neg chr6
# BigWig path: bigwigs/hg38/MCF10A/chr6/chr6.MCF10A.neg.bigWig
# Exists? True
# File size: 1.4GB
#
#
# MCF10A neg chr7
# BigWig path: bigwigs/hg38/MCF10A/chr7/chr7.MCF10A.neg.bigWig
# Exists? True
# File size: 1.3GB
#
#
# MCF10A neg chr8
# BigWig path: bigwigs/hg38/MCF10A/chr8/chr8.MCF10A.neg.bigWig
# Exists? True
# File size: 1.2GB
#
#
# MCF10A neg chr9
# BigWig path: bigwigs/hg38/MCF10A/chr9/chr9.MCF10A.neg.bigWig
# Exists? True
# File size: 1.0GB
#
#
# MCF10A neg chr10
# BigWig path: bigwigs/hg38/MCF10A/chr10/chr10.MCF10A.neg.bigWig
# Exists? True
# File size: 1.1GB
#
#
# MCF10A neg chr11
# BigWig path: bigwigs/hg38/MCF10A/chr11/chr11.MCF10A.neg.bigWig
# Exists? True
# File size: 1.1GB
#
#
# MCF10A neg chr12
# BigWig path: bigwigs/hg38/MCF10A/chr12/chr12.MCF10A.neg.bigWig
# Exists? True
# File size: 1.1GB
#
#
# MCF10A neg chr13
# BigWig path: bigwigs/hg38/MCF10A/chr13/chr13.MCF10A.neg.bigWig
# Exists? True
# File size: 0.8GB
#
#
# MCF10A neg chr14
# BigWig path: bigwigs/hg38/MCF10A/chr14/chr14.MCF10A.neg.bigWig
# Exists? True
# File size: 0.7GB
#
#
# MCF10A neg chr15
# BigWig path: bigwigs/hg38/MCF10A/chr15/chr15.MCF10A.neg.bigWig
# Exists? True
# File size: 0.7GB
#
#
# MCF10A neg chr16
# BigWig path: bigwigs/hg38/MCF10A/chr16/chr16.MCF10A.neg.bigWig
# Exists? True
# File size: 0.7GB
#
#
# MCF10A neg chr17
# BigWig path: bigwigs/hg38/MCF10A/chr17/chr17.MCF10A.neg.bigWig
# Exists? True
# File size: 0.7GB
#
#
# MCF10A neg chr18
# BigWig path: bigwigs/hg38/MCF10A/chr18/chr18.MCF10A.neg.bigWig
# Exists? True
# File size: 0.6GB
#
#
# MCF10A neg chr19
# BigWig path: bigwigs/hg38/MCF10A/chr19/chr19.MCF10A.neg.bigWig
# Exists? True
# File size: 0.4GB
#
#
# MCF10A neg chr20
# BigWig path: bigwigs/hg38/MCF10A/chr20/chr20.MCF10A.neg.bigWig
# Exists? True
# File size: 0.5GB
#
#
# MCF10A neg chr21
# BigWig path: bigwigs/hg38/MCF10A/chr21/chr21.MCF10A.neg.bigWig
# Exists? True
# File size: 0.3GB
#
#
# MCF10A neg chr22
# BigWig path: bigwigs/hg38/MCF10A/chr22/chr22.MCF10A.neg.bigWig
# Exists? True
# File size: 0.3GB
# =================== NaNs!!! 0.2701472228560688 50818468
#
#
# MCF10A neg chrX
# BigWig path: bigwigs/hg38/MCF10A/chrX/chrX.MCF10A.neg.bigWig
# Exists? True
# File size: 1.2GB
#
#
# MCF10A neg chrY
# BigWig path: bigwigs/hg38/MCF10A/chrY/chrY.MCF10A.neg.bigWig
# Exists? True
# File size: 0.2GB
# =================== NaNs!!! 0.5864351028261542 57227415

# %%
# after re-doing the broken ones:

# %%
for cell_type in cell_types:
    for strand in ["pos", "neg"]:
        print("\n")
        print(cell_type, strand)
        
        bw_path = get_bw_path(cell_type, strand)
        print("BigWig path:", bw_path)
        print("Exists?", os.path.exists(bw_path))
        
        # for hg38, this is about 24 GB
        print("File size:", "%0.1f" % (os.path.getsize(bw_path) / 1000000000) + "GB")
        
        try:
            bw = pyBigWig.open(bw_path, "r")
            
            a = bw.values("chr1", 103525338, 103525341, numpy=True)
            print("Some chr1 values:", a)
            
            bw.close()
        except:
            print("error")
            
        try:
            bw = pyBigWig.open(bw_path, "r")
            
            a = bw.values("chr17", 1000000, 1000003, numpy=True)
            print("Some chr17 values:", a)
            
            bw.close()
        except:
            print("error")
# Out:
# K562 pos
# BigWig path: bigwigs/hg38/K562/genomewide/K562.pos.bigWig
# Exists? True
# File size: 23.9GB
# Some chr1 values: [4.3629756e-05 1.7069968e-05 2.3992317e-04]
# Some chr17 values: [0.00444451 0.00309863 0.03139656]
#
#
# K562 neg
# BigWig path: bigwigs/hg38/K562/genomewide/K562.neg.bigWig
# Exists? True
# File size: 23.9GB
# Some chr1 values: [0.07293156 0.4248827  0.12350942]
# Some chr17 values: [0.00693997 0.01924002 0.00384026]
#
#
# A673 pos
# BigWig path: bigwigs/hg38/A673/genomewide/A673.pos.bigWig
# Exists? True
# File size: 24.0GB
# Some chr1 values: [1.5455839e-04 8.7890243e-05 1.0999229e-03]
# Some chr17 values: [0.00356467 0.00144409 0.01272652]
#
#
# A673 neg
# BigWig path: bigwigs/hg38/A673/genomewide/A673.neg.bigWig
# Exists? True
# File size: 24.0GB
# Some chr1 values: [0.06382322 0.4426282  0.11472011]
# Some chr17 values: [0.0115502  0.04067886 0.00563827]
#
#
# CACO2 pos
# BigWig path: bigwigs/hg38/CACO2/genomewide/CACO2.pos.bigWig
# Exists? True
# File size: 24.1GB
# Some chr1 values: [3.4407833e-05 6.6062939e-06 1.9196763e-04]
# Some chr17 values: [0.00238057 0.00151144 0.02050897]
#
#
# CACO2 neg
# BigWig path: bigwigs/hg38/CACO2/genomewide/CACO2.neg.bigWig
# Exists? True
# File size: 24.1GB
# Some chr1 values: [0.04377054 0.31369984 0.03337388]
# Some chr17 values: [0.01436719 0.04488569 0.00419833]
#
#
# CALU3 pos
# BigWig path: bigwigs/hg38/CALU3/genomewide/CALU3.pos.bigWig
# Exists? True
# File size: 24.0GB
# Some chr1 values: [2.6182146e-05 7.4259533e-06 3.0680851e-04]
# Some chr17 values: [0.00617397 0.00262399 0.03995492]
#
#
# CALU3 neg
# BigWig path: bigwigs/hg38/CALU3/genomewide/CALU3.neg.bigWig
# Exists? True
# File size: 24.0GB
# Some chr1 values: [0.03741201 0.27823198 0.03268407]
# Some chr17 values: [0.01715214 0.08494413 0.00613924]
#
#
# HUVEC pos
# BigWig path: bigwigs/hg38/HUVEC/genomewide/HUVEC.pos.bigWig
# Exists? True
# File size: 24.1GB
# Some chr1 values: [2.4300121e-05 8.9212926e-06 2.1424635e-04]
# Some chr17 values: [0.00258208 0.00068838 0.01353408]
#
#
# HUVEC neg
# BigWig path: bigwigs/hg38/HUVEC/genomewide/HUVEC.neg.bigWig
# Exists? True
# File size: 24.1GB
# Some chr1 values: [0.01194454 0.09232388 0.01221823]
# Some chr17 values: [0.00819649 0.03561141 0.00256181]
#
#
# MCF10A pos
# BigWig path: bigwigs/hg38/MCF10A/genomewide/MCF10A.pos.bigWig
# Exists? True
# File size: 24.0GB
# Some chr1 values: [6.8754052e-05 5.4270447e-05 6.4689136e-04]
# Some chr17 values: [0.00931177 0.00501466 0.0429942 ]
#
#
# MCF10A neg
# BigWig path: bigwigs/hg38/MCF10A/genomewide/MCF10A.neg.bigWig
# Exists? True
# File size: 24.0GB
# Some chr1 values: [0.05781263 0.40969297 0.0905821 ]
# Some chr17 values: [0.01938896 0.12604833 0.00963228]
